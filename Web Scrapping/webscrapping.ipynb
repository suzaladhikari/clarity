# %%
### Libraries to be imported
import pandas as pd 
import numpy as np 
import os 
import time
import requests

# %%
### Creating datasets for the top 20 companies 
watchlist = {
    "AAPL":  "Apple",
    "MSFT":  "Microsoft", 
    "NVDA":  "Nvidia",
    "GOOGL": "Alphabet (Google)",
    "AMD":  "AMD",
    "META":  "Meta (Facebook)",
    "TSLA":  "Tesla",
    "NFLX": "Netflix",
    "LLY":   "Eli Lilly",
    "AVGO":   "Broadcom",
    "MU":    "Micron Technology",
    "QCOM":   "Qualcomm",
    "UNH":   "UnitedHealth",
    "WMT":   "Walmart",
    "MA":    "Mastercard",
    "JNJ":   "Johnson & Johnson",
    "PG":    "Procter & Gamble",
    "HD":    "Home Depot",
    "ORCL":  "Oracle",
    "JPM": "JPMorgan Chase"
}

# %%
def company_datasets(symbol):
    path = '../updatedtop20datasets/'
    filepath = f'{path}{symbol}.csv'
    if os.path.exists(filepath):
        data = pd.read_csv(filepath)
        if "Symbol" not in data.columns:
            data["Symbol"] = symbol
            data.to_csv(filepath)
        print("Path already exists")
        return data
    API_KEY = '8e14d5babfe29c8815f268eb1afa1727ce18f16e'
    url_link = f"https://api.tiingo.com/tiingo/daily/{symbol}/prices"
    headers = {'Content-Type':'application/json'}
    params = {'startDate': '2008-01-01', 'token':API_KEY}
    respone = requests.get(url_link, headers = headers, params = params)
    data = respone.json()
    data = pd.DataFrame(data)
    if data.empty:
        print(f"There is no information for symbol {symbol}")
        return None
    data["Symbol"] = symbol
    data.to_csv(filepath, index = False)
    return data

# %%
data = company_datasets("AAPL")
data.head(5)
# Out:
# Path already exists
#                        date   close    high     low    open    volume  \
# 0  2008-01-02T00:00:00.000Z  194.84  200.26  192.55  199.27  38542100
# 1  2008-01-03T00:00:00.000Z  194.93  197.39  192.69  195.41  30073800
# 2  2008-01-04T00:00:00.000Z  180.05  193.00  178.89  191.45  51994000
# 3  2008-01-07T00:00:00.000Z  177.64  183.60  170.23  181.25  74006900
# 4  2008-01-08T00:00:00.000Z  171.25  182.46  170.80  180.14  54422000
#
#    adjClose   adjHigh    adjLow   adjOpen   adjVolume  divCash  splitFactor  \
# 0  5.832436  5.994681  5.763886  5.965046  1079179879      0.0          1.0
# 1  5.835131  5.908769  5.768077  5.849499   842067242      0.0          1.0
# 2  5.389705  5.777357  5.354981  5.730959  1455833455      0.0          1.0
# 3  5.317563  5.495973  5.095749  5.425627  2072195272      0.0          1.0
# 4  5.126282  5.461847  5.112811  5.392399  1523817523      0.0          1.0
#
#   Symbol
# 0   AAPL
# 1   AAPL
# 2   AAPL
# 3   AAPL
# 4   AAPL
