# %%
### Libraries to be imported
import pandas as pd 
import numpy as np 
import requests

# %%
## url link 
name = 'IBM'
url_link = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={name}&apikey=WJGSUHYQRBVMN7T5'
text = requests.get(url = url_link) ## .get command gives what is request in the url 
data = text.json()

# %%
time_series = data["Time Series (Daily)"]
print(time_series)
# Out:
# {'2026-05-22': {'1. open': '262.0500', '2. high': '264.3800', '3. low': '253.3900', '4. close': '253.8400', '5. volume': '19072873'}, '2026-05-21': {'1. open': '232.5800', '2. high': '253.6300', '3. low': '230.9350', '4. close': '252.9700', '5. volume': '25707791'}, '2026-05-20': {'1. open': '221.0500', '2. high': '225.0000', '3. low': '216.7800', '4. close': '225.0000', '5. volume': '4858990'}, '2026-05-19': {'1. open': '224.5000', '2. high': '227.3500', '3. low': '221.9200', '4. close': '222.3300', '5. volume': '5937754'}, '2026-05-18': {'1. open': '218.5500', '2. high': '223.3300', '3. low': '217.7500', '4. close': '222.7500', '5. volume': '5946367'}, '2026-05-15': {'1. open': '218.2000', '2. high': '220.9100', '3. low': '217.6150', '4. close': '219.3000', '5. volume': '6154450'}, '2026-05-14': {'1. open': '215.5450', '2. high': '220.9600', '3. low': '215.0000', '4. close': '218.3700', '5. volume': '5906199'}, '2026-05-13': {'1. open': '218.2700', '2. high': '218.3100', '3. low': 
# ...

# %%
columns = ['open', 'high', 'low', 'close', 'volume']
data = pd.DataFrame.from_dict(time_series, orient = 'index') ## We used from_dict becuase the time series was in the dictionary format 
data.head(5)
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# 2026-05-22  262.0500  264.3800  253.3900  253.8400  19072873
# 2026-05-21  232.5800  253.6300  230.9350  252.9700  25707791
# 2026-05-20  221.0500  225.0000  216.7800  225.0000   4858990
# 2026-05-19  224.5000  227.3500  221.9200  222.3300   5937754
# 2026-05-18  218.5500  223.3300  217.7500  222.7500   5946367

# %%
data = pd.DataFrame(data, columns=columns)
### Changing the date to datetime
data.index = pd.to_datetime(data.index)
data.head(5)
print(f"The data has {data.shape[0]} number of samples, and {data.shape[1]} number of features. The features in the dataset are {data.columns}")
# Out:
# The data has 100 number of samples, and 5 number of features. The features in the dataset are Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')
